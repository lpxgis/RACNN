# %%
# !python pretrain_apn.py
# Out:
#  :: Cleaning cache dir ...
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:2941: UserWarning: nn.functional.upsample is deprecated. Use nn.functional.interpolate instead.
#   warnings.warn("nn.functional.upsample is deprecated. Use nn.functional.interpolate instead.")
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:3121: UserWarning: Default upsampling behavior when mode=bilinear is changed to align_corners=False since 0.4.0. Please specify align_corners=True if the old behavior is desired. See the documentation of nn.Upsample for details.
#   "See the documentation of nn.Upsample for details.".format(mode))
# :: loss @step 0: 0.03390345722436905	avg_loss_5: 0.03390345722436905
# :: loss @step 1: 0.03594852238893509	avg_loss_5: 0.03492598980665207
# :: loss @step 2: 0.02085426077246666	avg_loss_5: 0.0302354134619236
# :: loss @step 3: 0.030792810022830963	avg_loss_5: 0.03037476260215044
# ...

# %%
# !python forge.py
# Out:
#  :: Cleaning cache dir ...
#  :: Start training with build/racnn_pretrained-1600680118.pt
#  :: Switch to backbone
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:2941: UserWarning: nn.functional.upsample is deprecated. Use nn.functional.interpolate instead.
#   warnings.warn("nn.functional.upsample is deprecated. Use nn.functional.interpolate instead.")
# :: loss @step(20/25)-epoch0: 13.8708629608	avg_loss_20: 22.9416947842
#  :: Switch to apn
# :: loss @step(20/25)-epoch0: 1.3806703091	avg_loss_20: 2.9522971928
#  :: Testing on test set ...
#  :: Switch to backbone
# :: loss @step(20/25)-epoch1: 66.0109710693	avg_loss_20: 67.2734666824
#  :: Switch to apn
# :: loss @step(20/25)-epoch1: 3.3816730976	avg_loss_20: 3.0485819161
#  :: Testing on test set ...
#  :: Switch to backbone
# :: loss @step(20/25)-epoch2: 34.9271202087	avg_loss_20: 59.1067391396
#  :: Switch to apn
# :: loss @step(20/25)-epoch2: 1.3765405416	avg_loss_20: 1.9408832684
# ...
